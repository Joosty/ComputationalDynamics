# %% [markdown]
# # Kinetics

# %% [markdown]
# You may recall that dynamics was principally divided into two key parts: __kinematics__ and __kinetics__. If you've followed along this far, here's a recap of our journey:
#   1. We have already examined kinematics in some detail. One must pause to take note here that, in this case, motion was investigated without considering the forces causing it.
#   2. Then, we introduced concepts such as mass/inertia scalars.
#   3. Next we focused on forces; moments; and the various types of momenta.
#
# This leads up to the final act: __kinetics__, which is the piece of the puzzle that relates the causes of motion (forces and moments) to the bodies. The law that connects them is one that you are likely already familiar with - Newton's Second Law. Quite simply put, this law states that the acceleration of a particle $P$ (for now, denoted as $\mathbf{a}$) is directly proportional to the force $\mathbf{F}$ acting on it. One may have also seen this law written as the following equation:
#
# ```{math}
# :label: dynamics1_NewtonsLawBasic
# {\mathbf F} = m{\mathbf a}
# ```
#
# In the following discussion, we dive deeper into this equation. A keen reader of this text may have already taken note that the vectors written here are incomplete when compared to our approach so far, i.e., our typical vector notations make use of super-scripts (and subscripts, in some cases) to specify reference frames, particles, bodies, etc.
#
# <!--   This is what we will expound on that permits us to precisely -->
# <!--   define the dynamics in a manner consistent with what we have followed so far. -->

# %% [markdown]
# ## Key Concept: Inertial Frame

# %% [markdown]
# In our discussions within kinematics, we have described positions in space of objects (i.e., points and reference frames) relative to some other reference frame by means of linear and angular measurements. In many cases, we made use of reference frames that were fixed (i.e., the ground).
#
# Newton’s laws of mechanics are valid in a frame known as an **inertial reference frame** (or **inertial frame** or **Newtonian frame**).
#
# - **Definition 1**: Textbooks often define something known as a primary inertial system, which is a reference frame that is neither translating nor rotating in space. The laws of Newton are said to hold in this frame; experiments show that the laws are valid in such a frame as long as the velocities involved are negligible compared with the speed of light, which is 300,000 km/s. Consequently, for several engineering problems, the Earth can be approximated to an inertial frame in studying the motion of objects moving on it (like cars) and close to it (spacecraft in Low Earth Orbit).
#
# - **Definition 2**: It is also seen that Newton’s laws hold in any non-rotating reference frame that moves with a constant velocity; the time derivative of a constant velocity leads to zero acceleration. Thus, another definition emerges for an inertial frame as a frame which has zero acceleration (or is a non-accelerating reference frame).
#
# As a result of the two definitions above, you will also commonly see books define an inertial frame in a rather circuitous manner as a frame in which Newton’s second law is valid. Now you know why.

# %% [markdown]
# ## Equations of motion

# %% [markdown]
# Newton’s second law (as stated above) is a vector equation; indeed, they can be written as 3 scalar equations called **Equations of Motion**.
#
# $$
#     \mathbf{\vec{F}} = m\mathbf {\vec{a}} \Longrightarrow
#     \begin{cases}
#       \mathbf{F_x} = m\mathbf{a_x} \\
#       \mathbf{F_y} = m\mathbf{a_y} \\
#       \mathbf{F_z} = m\mathbf{a_z} \\
#     \end{cases}
# $$
#
# The above equations can be used to solve two types of problems:
#   * **Acceleration is known and we have to calculate the forces**: Acceleration is either specified or can be determined directly from known kinematic conditions. The corresponding forces on the particle can then be directly determined from Newton’s Second Law.
#
#   * **Forces are known and motion needs to be determined**:
#       - **Case 1**: If the forces are constant, the acceleration is also constant and is easily found using the equations of motion.
#
#       - **Case 2**: In the most general case, forces are functions of time, position, or velocity; so the above set of equations are differential equations. These are more challenging problems. Deriving these general equations is the goal of this portion of the module.

# %% [markdown]
# ## Free body diagrams to determine forces

# %% [markdown]
# - Developing equations of motion requires that you account correctly for all forces acting on any object.
#
# - The only reliable way to account for every force is to isolate the particle under consideration from all contacting and influencing bodies and replace the bodies removed by the forces they exert on the particle isolated.
#
# ```{attention}
# Note that not all the forces are known in terms of their magnitude e.g., reaction forces (this will become clearer later); but we need to account for all forces at a qualitative level in our free-body diagram.
# ```
# The types of forces to account for are:

# %% [markdown]
# <!-- This part may need to be fixed, need to ask questions -->
#
# **Gravitational Forces**:
#
# The gravitational force between two masses is given by:
#
# $$
# F = \frac{Gm_1m_2}{r^2}
# $$
#
# where $G$ is the gravitational constant, $m_1$ and $m_2$ are the masses of the objects, and $r$ is the distance between their centers.
#
# **Friction Forces**:
#
# - **Dynamic** friction forces are those that oppose the movement of an object already in motion. They are generally less than static friction forces and are described by:
#
#   $$
#   F_{\text{dynamic}} = \mu_d N
#   $$
#
#   where $\mu_d$ is the coefficient of dynamic friction and $N$ is the normal force.
#
# - **Static** friction forces prevent an object from moving while it is at rest. The maximum static friction force is given by:
#
#   $$
#   F_{\text{static}} \leq \mu_s N
#   $$
#
#   where $\mu_s$ is the coefficient of static friction.
#
# **Spring Forces**:
#
# The force exerted by a spring is described by Hooke's Law:
#
# $$
# F = -k x
# $$
#
# where $k$ is the spring constant and $x$ is the displacement from the equilibrium position.
#
#
# <!-- Improve this part -->
#
# ```{figure} ./images/spring-forces.png
# ---
# name: spring-forces
# ---
# Spring forces

# %% [markdown]
# ## Types of motion
# There are two physically distinct types of motion:
#
# - **Unconstrained motion**: where the moving object is free of mechanical guides and follows a path determined by its initial motion and by the forces which are applied to it from external sources. An example here is the motion of a satellite or a rocket in flight.
# - **Constrained motion**: where the moving object is partially or totally restrained by guides. Thus, in addition to external forces, there are also reaction forces that emerge. An example of fully constrained motion is of a train moving along a track. The motion of a car is another example as it is constrained to move on the horizontal plane.

# %% [markdown]
# ## Kinetics of a Single Particle: Unconstrained Motion

# %% [markdown]
# For a particle $P$, moving relative to a frame $N$ under the influence of an external force $F$, we have Newton’s second law:
#
# $$\mathbf{\vec{F}} = m^{N}\mathbf{\vec{a}}^P$$

# %% [markdown]
# **Practical example**: The case of motion of a $S$, a spacecraft, about the Earth:
#
# ```{attention}
# **GOAL**: To find the equations of motion of $S$.
# ```
# Prior to any equations, each term required must be defined.
#
# $m_1$ = Mass of the Earth
#
# $m_2$ = Mass of the Spacecraft
#
# $\mathbf{\vec{r}}$ = Position vector from $O$ to $S$
#
# $\theta$ = Inclination of position vector
#
# $N$ = Earths inertial reference frame
#
# ```{figure} ./images/earth-sat-1.png
# ---
# name: earth-sat-1
# ---
# ```
#
# Using **cartesian coordinates** the position and velcoity vectors can be defined.
#
# $$\mathbf{\vec{r}} = x\hat{n_x}+y\hat{n_y}$$
#
# $${}^{N}{\mathbf{\vec{v}}}^{S} =  {}^{N}{\frac d {\mathrm{d}t}}\mathbf{\vec{r}} = \dot{x}\hat{n_x}+\dot{y}\hat{n_y}$$
#
#
# ```{figure} ./images/earth-sat-2.png
# ---
# name: earth-sat-2
# ---
# ```
# The acceleration vector can then be defined as:
#
# $${}^{N}{\mathbf{\vec{a}}}^{S} = {}^{N}{\frac d {\mathrm{d}t}}{}^{N}{\mathbf{\vec{v}}}^{S} =  {}^{N}{\frac d {\mathrm{d}t}}(\dot{x}\hat{n_x}+\dot{y}\hat{n_y})$$
#
# $${}^{N}{\mathbf{\vec{a}}}^{S} = \ddot{x}\hat{n_x}+\ddot{y}\hat{n_y}$$
#
# $${F_g}=\frac{G{m_1}{m_2}}{|\mathbf{\vec{r}}|^{2}}$$
#
# $$\mathbf{\vec{F}} = -{F_g}(cos\theta\hat{n_x}+sin\theta\hat{n_y})$$
#
# From this it can be seen that $\mathbf{\vec{F}} = m\mathbf{\vec{a}}$ gives two scalar equations - displayed below.
#
# <!-- Not sure on x/y dim stuff  -->
#
#
# $${Xdim}-{F_g}cos\theta = \ddot{x}{m_2}$$
#
# $${Ydim}-{F_g}sin\theta = \ddot{y}{m_2}$$
#
#
# ```{figure} ./images/earth-sat-3.png
# ---
# name: earth-sat-3
# ---
# ```
#
# Now, making use of **Polar Coordinates**...
#
# $$\mathbf{\vec{r}}=r{\hat{e_r}}$$
#
# $${}^{N}\mathbf{\vec{v}}^{S} \triangleq {}^{N}{\frac d {\mathrm{d}t}}{}^{N}\mathbf{\vec{r}}^{S} = {}^{N}{\frac d {\mathrm{d}t}}r{\hat{e_r}}$$
#
#
# ```{figure} ./images/earth-sat-4.png
# ---
# name: earth-sat-4
# ---
# ```
# $${}^{N}\mathbf{\vec{v}}^{S} \triangleq {}^{N}{\frac d {\mathrm{d}t}}{}^{N}\mathbf{\vec{r}}^{S} = {}^{N}{\frac d {\mathrm{d}t}}r{\hat{e_r}}$$
#
# $$= {}^{E}{\frac d {\mathrm{d}t}}(r{\hat{e_r}})+{}^{N}\boldsymbol{\vec{\omega}}^{E} \times r{\hat{e_r}}$$
#
# $$= \dot{r}{\hat{e_r}}+\dot{\theta}{\hat{e_z}} \times {r}{\hat{e_r}}$$
#
# $$= \dot{r}{\hat{e_r}}+r\dot{\theta}{\hat{e_\theta}}$$
#
# <!-- could remove -->
# ---
#
# $${}^{N}\mathbf{\vec{a}}^{S} = {}^{N}{\frac d {\mathrm{d}t}}{}^{N}\mathbf{\vec{v}}^{S} = {}^{E}{\frac d {\mathrm{d}t}}{}^{N}\mathbf{\vec{v}}^{S} + {}^{N}\boldsymbol{\vec{\omega}}^{E} \times {}^{N}\mathbf{\vec{v}}^{S}$$
#
# $$= {}^{E}{\frac d {\mathrm{d}t}}(\dot{r}{\hat{e_r}} + {r}\dot{\theta}{\hat{e_\theta}}) + \dot{\theta}{\hat{e_z}} \times (\dot{r}{\hat{e_r}} + {r}\dot{\theta}{\hat{e_\theta}})$$
#
# <!-- could remove -->
# ---
#
# $${}^{N}\mathbf{\vec{a}}^{S} = (\ddot{r}-r{\dot{\theta}^2}){\hat{e_r}} + (2\dot{r}\dot{\theta}+r\ddot{\theta})\hat{e_\theta}$$
#
# $\mathbf{\vec{F}} = {m_2} {}^{N}\mathbf{\vec{a}}^{S}$ for this satellite...
#
# $$-F_g = {m_2}(\ddot{r}-\dot{r}\theta^2) \rightarrow \hat{e_r} \text{ direction}$$
#
# $$0 = {m_2}(2{\dot{r}\dot{\theta}}-{r}\ddot{\theta}) \rightarrow \hat{e_\theta} \text{ direction}$$
#
# ```{figure} ./images/earth-sat-5.png
# ---
# name: earth-sat-5
# ---
# ```
# **For the Earth:**
#
# $$\mathbf{\vec{F}_{Earth}} = {m_1} {}^{A}{\frac{d^2}{\mathrm{d}t^2}}\mathbf{\vec{r}_{1}} = m_1\ddot{\mathbf{\vec{r}}}_{1} + {F_g}{\hat{e_r}} = m_1\ddot{\mathbf{\vec{r}}}_{1}$$
#
#
# **For the Spacecraft:**
#
# $$\mathbf{\vec{F}_{Spacecraft}} = {m_2} {}^{A}{\frac{d^2}{\mathrm{d}t^2}}\mathbf{\vec{r}_{2}} = m_2\ddot{\mathbf{\vec{r}}}_{2} - {F_g}{\hat{e_r}} = m_2\ddot{\mathbf{\vec{r}}}_{2}$$
#
# ```{figure} ./images/earth-sat-6.png
# ---
# name: earth-sat-6
# ---
# ```
# Now you can add both equations. This gives:
#
# $${F_g}{\hat{e_r}} - {F_g}{\hat{e_r}} = m_1\ddot{\mathbf{\vec{r}}}_{1} + m_2\ddot{\mathbf{\vec{r}}}_{2}$$
#
# $$ 0 = m_1\ddot{\mathbf{\vec{r}}}_{1} + m_2\ddot{\mathbf{\vec{r}}}_{2}$$
#
#
#
# ```{figure} ./images/earth-sat-7.png
# ---
# name: earth-sat-7
# ---
# ```
# ```{hint}
# Recall that, systems of particles have a fictitious point called the mass centre; let's call it $G$ in this case (see figure). In this scenario, we have the definition of the mass centre as:
# ```
#
# $${m_1} {\mathbf{\vec{r}}}_{1} + {m_2} {\mathbf{\vec{r}}}_{2} = \left(\sum_{i=1}^2 m_i\right) {\mathbf{\vec{r}}}_{G}$$
#
# Consequently, we can get:
#
# $${m_1} {}^{A} {\frac{d}{\mathrm{d}t}} {\mathbf{\vec{r}}}_{1} + {m_2}  {}^{A} {\frac{d}{\mathrm{d}t}} {\mathbf{\vec{r}}}_{2} = \left(\sum_{i=1}^2 m_i\right) {}^{A} {\frac{d}{\mathrm{d}t}} {\mathbf{\vec{r}}}_{G}$$
#
# And:
#
# $${m_1} {}^{A} {\frac{d}{\mathrm{d}t}} {\mathbf{\vec{r}}}_{1} + {m_2}  {}^{A} {\frac{d}{\mathrm{d}t}} {\mathbf{\vec{r}}}_{2} = \left(\sum_{i=1}^2 m_i\right) {}^{A} {\frac{d}{\mathrm{d}t}} {\mathbf{\vec{r}}}_{G}$$
#
# $${m_1} {}^{A} {\frac{d^2}{\mathrm{d}t}} {\mathbf{\vec{r}}}_{1} + {m_2}  {}^{A} {\frac{d^2}{\mathrm{d}t}} {\mathbf{\vec{r}}}_{2} = \left(\sum_{i=1}^2 m_i\right) {}^{A} {\frac{d^2}{\mathrm{d}t}} {\mathbf{\vec{r}}}_{G} \tag{11.2}$$
#
# ```{figure} ./images/earth-sat-8.png
# ---
# name: earth-sat-8
# ---
# ```
# Equation $11.2$ can be rewritten using $11.1$ as:
#
# $$\left(\sum_{i=1}^2 m_i\right) {}^{A}{\mathbf{\vec{a}}}_{G}$$
#
# or:
#
# $${}^{A}{\mathbf{\vec{a}}}_{G} = 0$$
#
# Which also implies:
#
# $${}^{A}{\mathbf{\vec{v}}}_{G} = \text{constant}$$
#
#
# ```{figure} ./images/earth-sat-9.png
# ---
# name: earth-sat-9
# ---
# ```

# %% [markdown]
# In this second discussion, we have considered the motion of a system containing two particles: one being the spacecraft and the other being the Earth. First, we studied the motion of each particle from an inertial frame. Subsequently, we combined this information to study the motion of the two-particle system from its combined mass centre, denoted as $G$.
#
# It turns out that this development of Newton’s second law for two-particles actually generalizes to a system comprising $n$ particles and also to a rigid body. We examine this further in teh following section.

# %% [markdown]
# ## Generalized Newton’s Second Law

# %% [markdown]
# Consider a system of $n$ particles and an inertial frame $N$. Each particle experiences an external resultant force and a set of internal forces. The internal forces are reaction forces applied by each particle on all other particles within the boundary.
#
# ```{figure} ./images/earth-sat-10.png
# ---
# name: earth-sat-10
# ---
# ```
# We can now write the equations of motion for each of the particles:
#
# **For $\mathbf{P_1}$**
#
# $${\mathbf{\vec{F}}_1} + {\mathbf{\vec{f}}_12} + {\mathbf{\vec{F}}_1n} + {\mathbf{\vec{F}}_1i} = {m_1}{}^{N}{\mathbf{a}}^{p_1}$$
#
# $${\mathbf{\vec{F}}_1} + \sum_{k=1}^n {\mathbf{\vec{f}}_{1k}} = {m_1}{{}^{N}{\mathbf{\vec{a}}}^{p_1}} \tag{11.3}$$
#
# **For $\mathbf{P_2}$**
#
# $${\mathbf{\vec{F}}_2} + \sum_{k=1}^n {\mathbf{\vec{f}}_{2k}} = {m_2}{{}^{N}{\mathbf{\vec{a}}}^{p_2}} \tag{11.4}$$
#
# **For $\mathbf{P_i}$**
# $${\mathbf{\vec{F}}_i} + \sum_{k=1}^n {\mathbf{\vec{f}}_{ik}} = {m_i}{{}^{N}{\mathbf{\vec{a}}}^{p_i}} \tag{11.5}$$
#
# **For $\mathbf{P_n}$**
#
# $${\mathbf{\vec{F}}_n} + \sum_{k=1}^n {\mathbf{\vec{f}}_{nk}} = {m_n}{{}^{N}{\mathbf{\vec{a}}}^{p_n}}\tag{11.6}$$
#
# We can now add up all the equations form $11.3$ to $11.6$ to get...
#
# ```{figure} ./images/earth-sat-11.png
# ---
# name: earth-sat-11
# ---
# ```
# $$\sum_{k=1}^n {\mathbf{\vec{f}}_{k}} + \sum_{j=1}^n {\mathbf{\vec{f}}} \sum_{k=1}^n {\mathbf{\vec{f}}_{jk}} = \sum_{k=1}^n ({m_k}{{}^{N}{\mathbf{\vec{a}}}^{p_k}}) \tag{11.6}$$
#
# Where:
#
# - $\sum_{k=1}^n {\mathbf{\vec{f}}_{k}}$ is the resultant external force on the system.
# - $\sum_{j=1}^n {\mathbf{\vec{f}}} \sum_{k=1}^n {\mathbf{\vec{f}}_{jk}}$ is the sum of all internal forces.
#
# If the sum of all internal forces is deemed to be zero..
#
# $$\sum_{k=1}^n {\mathbf{\vec{f}}_{k}} + \cancel{\sum_{j=1}^n {\mathbf{\vec{f}}} \sum_{k=1}^n {\mathbf{\vec{f}}_{jk}}} = \sum_{k=1}^n ({m_k}{{}^{N}{\mathbf{\vec{a}}}^{p_k}})$$
#
# So,
#
# $$\sum_{k=1}^n {\mathbf{\vec{f}}_{k}} = \sum_{k=1}^n ({m_k}{{}^{N}{\mathbf{\vec{a}}}^{p_k}})$$
#
# Or,
#
# $$\sum_{k=1}^n {\mathbf{\vec{f}}_{k}} = \left(\sum_{k=1}^n {m_k}\right) {{}^{N}{\mathbf{\vec{a}}}^{S^*}}$$
#
# $${\mathbf{\vec{f}}} = {m} {{}^{N}{\mathbf{\vec{a}}}^{S^*}}$$
#
# Where $S^*$ is the mass centre of the system of particles.
#
#
#
# ```{figure} ./images/earth-sat-12.png
# ---
# name: earth-sat-12
# ---
# ```
#
# So far, everything we have studied addresses the kinetics of a point mass; the point mass was either a particle (e.g., a satellite) or a mass centre of a system of particles. This only describes the translational motion or the translational dynamics, which is based on Newton’s second law (the time derivative of linear momentum is equal to forces acting on a system). So what about the rotational dynamics?

# %% [markdown]
# ## Rotational dynamics

# %% [markdown]
# Much like how the translational dynamics inherently makes use of the concepts of linear momentum and forces, the rotational dynamics can be studied by making use of angular momentum (moment of linear momentum) and moments of forces.
#
# In this next section, e will derive the relevant equations by making use of the system of particles from before (also shown in figure below). We also introduce a point $O$ as we know that the concept of a moment of a vector is defined relative to some point in space.

# %% [markdown]
# ```{figure} ./images/earth-sat-13.png
# ---
# name: earth-sat-13
# ---
# ```
#
# We now begin by considering the equation of translational motion for $P_1$:
#
# $${\mathbf{\vec{F}}_1} + \sum_{k=1}^n {\mathbf{\vec{f}}_{1k}} = {m_1}{{}^{N}{\mathbf{\vec{a}}}^{p_1}} \tag{11.3}$$
#
# ```{figure} ./images/earth-sat-14.png
# ---
# name: earth-sat-14
# ---
# ```
# We can cross multiply it on both the right and left sides by $\vec{r}_1$, the position vector from $O$ to $P_1$:
#
# $${\vec{r}_1} \times ({\mathbf{\vec{F}}_1} + \sum_{k=1}^n {\mathbf{\vec{f}}_{1k}}) = {\vec{r}_1} \times {m_1}{{}^{N}{\mathbf{\vec{a}}}^{p_1}} \tag{11.8}$$
#
# ```{figure} ./images/earth-sat-15.png
# ---
# name: earth-sat-15
# ---
# ```
#
# In essence, what we have done is taken the moment about point $O$ of vectors on the right and left hand sides.
#
# We can repeat this process for the other particles $P_2$, $P_i$, and $P_n$. In other words, we can take the moment about point $O$ for each particle’s translational equations, as given by equations $11.4$, $11.5$, and $11.6$.
#
# **For $\mathbf{P_2}$**
#
# $${\vec{r}_2} \times {\mathbf{\vec{F}}_2} + \sum_{k=1}^n {\mathbf{\vec{f}}_{2k}} = {\vec{r}_2} {m_2}{{}^{N}{\mathbf{\vec{a}}}^{p_2}} \tag{11.9}$$
#
# **For $\mathbf{P_i}$**
# $${\vec{r}_i}{\mathbf{\vec{F}}_i} + \sum_{k=1}^n {\mathbf{\vec{f}}_{ik}} = {\vec{r}_i}{m_i}{{}^{N}{\mathbf{\vec{a}}}^{p_i}} \tag{11.10}$$
#
# **For $\mathbf{P_n}$**
#
# $${\vec{r}_n}{\mathbf{\vec{F}}_n} + \sum_{k=1}^n {\mathbf{\vec{f}}_{nk}} = {\vec{r}_n}{m_n}{{}^{N}{\mathbf{\vec{a}}}^{p_n}}\tag{11.11}$$
#
# ```{figure} ./images/earth-sat-16.png
# ---
# name: earth-sat-16
# ---
# ```
# We can now add up equations $11.8 and $11.11$ to get:
#
# $$\sum_{j=1}^n {\mathbf{\vec{r}}_{j}} \times {\mathbf{\vec{F}}_{j}} + \sum_{j=1}^n \sum_{k=1}^n {\mathbf{\vec{r}}_{j}} \times {\mathbf{\vec{f}}_{jk}} = \sum_{j=1}^n {\mathbf{\vec{r}}_{j}} \times ({m_j}{{}^{N}\mathbf{\vec{a}}^{p_j}}) \tag{11.12}$$
#
#
# ```{figure} ./images/earth-sat-17.png
# ---
# name: earth-sat-17
# ---
# ```
#
# Let’s examine each term of equation $11.12$:
#
# The first term, $\sum_{j=1}^n {\mathbf{\vec{r}}_{j}} \times {\mathbf{\vec{F}}_{j}}$, is the sum of moments of the external forces about the point $O$.
#
# The second term, $\sum_{j=1}^n \sum_{k=1}^n {\mathbf{\vec{r}}_{j}} \times {\mathbf{\vec{f}}_{jk}}$, can be proven to be zero. Take time to do this independently to help with your understanding.
#
# <!-- do this proof ^^ put in dropdown -->
#
# The third term, $\sum_{j=1}^n {\mathbf{\vec{r}}_{j}} \times ({m_j}{{}^{N}\mathbf{\vec{a}}^{p_j}})$, is a more complex term. Examination starts by looking at the defination of angular  of a syetm of particles, giuven below:
#
# $${}^{N}{\mathbf{\vec{H}}}^{S/O} = \sum_{j=1}^n {{\mathbf{\vec{r}}}_j} \times {m_j}{{}^{N}\mathbf{\vec{v}}^{p_j}}$$
#
#
# ```{figure} ./images/earth-sat-18.png
# ---
# name: earth-sat-18
# ---
# ```
#
# So, the time derivative of this system’s angular momentum vector taken from the inertial frame $N$ is given as:
#
#
# $$ {}^{N}{\frac d {\mathrm{d}t}} {}^{N}{\mathbf{\vec{H}}}^{S/O} = \left(\sum_{j=1}^n {}^{N}{\frac d {\mathrm{d}t}} {{\mathbf{\vec{r}}}_j} \times {m_j}{{}^{N}\mathbf{\vec{v}}^{p_j}}\right) + \left(\sum_{j=1}^n {}^{N}{{\mathbf{\vec{r}}}_j} \times {m_j}{{}^{N}\mathbf{\vec{a}}^{p_j}}\right) $$
#
# $$\left(\sum_{j=1}^n {}^{N}{{\mathbf{\vec{r}}}_j} \times {m_j}{{}^{N}\mathbf{\vec{a}}^{p_j}}\right) = {}^{N}{\frac d {\mathrm{d}t}} {}^{N}{\mathbf{\vec{H}}}^{S/O} + \left(\sum_{j=1}^n {{\mathbf{\vec{r}}}_j} \times {m_j}{{}^{N}\mathbf{\vec{a}}^{p_j}}\right) \tag{11.13}$$
#
#
# ```{figure} ./images/earth-sat-19.png
# ---
# name: earth-sat-19
# ---
# ```
# So, $11.12$ becomes:
#
# $$\sum {\mathbf{\vec{M}}}^{{{\mathbf{\vec{F}}}_i}/O} = {\frac d {\mathrm{d}t}} {}^{N}{\mathbf{\vec{H}}}^{S/O} + \left(\sum_{j=1}^n {{\mathbf{\vec{r}}}_j} \times {m_j}{{}^{N}\mathbf{\vec{a}}^{p_j}}\right) \tag{11.13}$$
#
# Where $\sum {\mathbf{\vec{M}}}^{{{\mathbf{\vec{F}}}_i}/O}$ is the sum of moments of the external forces about the point $O$.
#
# By introdcuing a point, $Q$, fixed in inertial frame $N$ and defining two new position vectors as shown below, we can further synthesise the expression ${{}^{N}\mathbf{\vec{a}}^{p_j}}$ in terms of mass centres. Hence we can see:
#
# $${\mathbf{\vec{r}}}_j = {\mathbf{\vec{R}}}_j - {\mathbf{\vec{r}}}$$
#
# and
#
# $${\frac d {\mathrm{d}t}} {\mathbf{\vec{r}}}_j = {}^{N}{\mathbf{\vec{v}}}^{p_j} - {}^{N}{\mathbf{\vec{v}}}^{O}$$
#
#
# ```{figure} ./images/earth-sat-20.png
# ---
# name: earth-sat-20
# ---
# ```
#
# So, $11.13$ can now be rewritten finally in a much simpler form as:
#
# $$\sum{\mathbf{\vec{M}}}^{{{\mathbf{\vec{F}}}_i}/{O}} = {}^{N}{\frac d {\mathrm{d}t}} {}^{N}{\mathbf{\vec{H}}}^{S/O} - \left(\sum_{j=1}^n m_j {}^{N}{\mathbf{\vec{v}}}^{p_j}\right) \times {}^{N}{\mathbf{\vec{v}}}^{O}$$
#
# Or...
#
# $$\sum{\mathbf{\vec{M}}}^{{{\mathbf{\vec{F}}}_i}/{O}} = {}^{N}{\frac d {\mathrm{d}t}} {}^{N}{\mathbf{\vec{H}}}^{S/O} - \left(m {}^{N}{\mathbf{\vec{v}}}^{S^*}\right) \times {}^{N}{\mathbf{\vec{v}}}^{O}$$
#
#
# It is important to note two special cases:
#
# 1. $O$ is fixed in $N$:
#
# $$\sum{\mathbf{\vec{M}}}^{{{\mathbf{\vec{F}}}_i}/{O}} = {}^{N}{\frac d {\mathrm{d}t}} {}^{N}{\mathbf{\vec{H}}}^{S/O}$$
#
# 2. $O$ is the mass centre $S^*$:
#
# $$\sum{\mathbf{\vec{M}}}^{{{{\mathbf{\vec{F}}}_i}/{S^*}}} = {}^{N}{\frac d {\mathrm{d}t}} {}^{N}{\mathbf{\vec{H}}}^{S/{S^*}}$$
#
#
# ```{figure} ./images/earth-sat-21.png
# ---
# name: earth-sat-21
# ---
# ```

# %% [markdown]
# **Kinetics Summary**
# The topics covered up until this point are briefly summarised in this section as a refresher to help with understanding.
#
# We began by examining the equations of motion of a single particle $P$ by Newton’s second law:
#
# $$
# \mathbf{\vec{F}} = m^N\mathbf{\vec{a}}^p
# $$
#
# Then, we looked at a system of two particles and used that as a stepping stone towards deriving a generalised Newton’s second law for a system of any number of particles. This resulted in:
#
# $$
# \mathbf{\vec{F}} = m{}^N\mathbf{\vec{a}}^{S^*}
# $$
#
# Where:
# - $\mathbf{\vec{F}}$ is the resultant force on the system,
# - $m$ is the total mass,
# - ${}^N\mathbf{\vec{a}}^{S^*}$ is the acceleration of the mass centre.
#
#
# ```{figure} ./images/earth-sat-22.png
# ---
# name: earth-sat-22
# ---
# ```
# We then used the generalized Newton’s second law to derive the rotational dynamics of the system relative to a frame $N$ by taking the moment of the translational motion about some arbitrary point $O$. The equations for rotational motion were then found to be:
#
# $$\sum{\mathbf{\vec{M}}}^{{{\mathbf{\vec{F}}}_i}/{O}} = {}^{N}{\frac d {\mathrm{d}t}} {}^{N}{\mathbf{\vec{H}}}^{S/O} - \left(m {}^{N}{\mathbf{\vec{v}}}^{S^*}\right) \times {}^{N}{\mathbf{\vec{v}}}^{O}$$
#
# Where:
# - $\sum{\mathbf{\vec{M}}}^{{{\mathbf{\vec{F}}}_i}/{O}}$ is the sum of moments from external forces,
# - ${}^{N}{\frac d {\mathrm{d}t}} {}^{N}{\mathbf{\vec{H}}}^{S/O}$ is the rate of change of ${\mathbf{\vec{H}}}$ of $S$ about $O$.
#
# ```{figure} ./images/earth-sat-23.png
# ---
# name: earth-sat-23
# ---
# ```

# %% [markdown]
# As this rotational equation was derived from the generalized Newton’s law, this result is also general. By that, we mean that this applies to general 3D rotational motion of a system of particles, $S$, relative to an inertial frame, $N$. Therefore, it can be easily used to study more specific types of planar motion (e.g., rotation about a fixed axis and general plane motion) by starting from this general set of equations and applying appropriate analysis to the given problem.
#
# Lastly, we saw that the above equation simplifies when the point $O$ is either:
# * **case 1**: a point that is fixed in an inertial frame; and/or
# * **case 2**: the mass centre.
#
# In both cases, the last term involving cross products on the right-end side of the rotational equation drop out.

# %% [markdown]
# ## Translational and Rotational Kinetics of a Rigid Body

# %% [markdown]
# <!-- Break 20/08/2024 -->
#
# ```{important}
# The generalized equations of translational and rotational motion that have been stated above for a system of particles are equally valid for the rigid body; shown below is a rigid body $B$ in general 3D rotation (see Lecture 4 rigid body `kinematics_ orientations.pdf` for classification of types of motion). The equations of motion this body are given as follows:
#
# **Translational:**
#
# $$\sum \mathbf{\vec{F}}_i = m_B {}^{N}{\mathbf{\vec{a}}}^{B^*} $$
#
# **Rotational:**
#
# $$\sum{\mathbf{\vec{M}}}^{{{\mathbf{\vec{F}}}_i}/{B^*}} + \sum \mathbf{\vec{M}}_i = {}^{N}{\frac d {\mathrm{d}t}} {}^{N}{\mathbf{\vec{H}}}^{B/{B^*}}$$
#
# ```
#
# ```{figure} ./images/earth-sat-24.png
# ---
# name: earth-sat-24
# ---
# ```
#
# Let's briefly examine the rotational equation further. Now, we know that:
#
# $${}^{N}{\mathbf{\vec{H}}}^{B/{B^*}} = \left[I \right]^{B/B^*}\cdot {}^{N}{\boldsymbol{\vec{\omega}}}^B$$
#
# ```{figure} ./images/earth-sat-25.png
# ---
# name: earth-sat-25
# ---
# ```
#
# Now if the inertia scalars of $B$ about $B^*$ are defined in the $B$ frame; for example:
#
# $${I_{xy}}^{B/B^*} \triangleq \int$$
#
# ```{figure} ./images/earth-sat-26.png
# ---
# name: earth-sat-26
# ---
# ```
# ```{figure} ./images/earth-sat-27.png
# ---
# name: earth-sat-27
# ---
# ```

# %% [markdown]
# So, now we can look at what happens to the scalar equations of motion in each of the directions. We do so for two
# cases:
#
# ```{figure} ./images/earth-sat-28.png
# ---
# name: earth-sat-28
# ---
# ```
#
# **Example 2**:
#
# ```{figure} ./images/earth-sat-29.png
# ---
# name: earth-sat-29
# ---
# ```
#
# The system shown in the figure above
# consists of a pulley constrained to rotate
# about its centre of mass $G$. A light cord
# is wrapped around the pulley and the
# free end is attached to a mass of $10\;kg$.
# The radius of the pulley is $0.15\;m$ and its
# moment of inertia about $G$ is $0.4\;kgm^2$.
#
# If the mass is released from rest what
# will be its velocity after one revolution of
# the pulley.
#
# ```{figure} ./images/earth-sat-30.png
# ---
# name: earth-sat-30
# ---
# ```
#
# With reference to the free body diagram
# above, the pulley is constrained to rotate
# about its centre of mass, $G$. Therefore
# the only equation of motion of
# importance is the balance of moments
# about the pulleys centre of mass as
# follows:
#
# $$
# \sum|\mathrm{\boldsymbol{M}_G}| = \bar{I}\alpha = \bar{I}\ddot{\theta}
# $$
#
# Therefore,
#
# $$
# Tr=\bar{I}\ddot{\theta}
# $$
#
# And for the mass, motion is in the
# x-direction only with no rotation.
#
# $$
# Mg-T=M\ddot{x}
# $$
#
# Finally, from geometry,
#
# $$
# \theta = \frac{x}{r}
# $$
#
# Therefore,
#
# $$
# \dot{\theta} = \frac{\dot{x}}{r}
# $$
#
# And
#
# $$
# \ddot{\theta} = \frac{\ddot{x}}{r}
# $$
#
# Hence we have three equations and three unknowns, $T$, $\ddot{x}$ and $\ddot{\theta}$.
#
# Eliminating $T$ and $\ddot{\theta}$ leaves:
#
# $$
# \ddot{x} = \frac{Mg}{\left(\frac{\bar{I}}{r^2} + M\right)} = \frac{10\times9.81}{\left(\frac{0.14}{0.15^2} + 10\right)} = 3.52 \;m/s^2 = \mathrm{constant}
# $$
#
# After one revolution, the mass will have
# traveled a distance, $s = 2\times S \times 0.15
# = 0.942\;m$. For constant acceleration
# and zero initial velocity,
#
# $$
# \nu = \sqrt{2as} = \sqrt{2 \times 3.53 \times 0.942} = 2.58\;m/s
# $$
#
# ```{figure} ./images/earth-sat-31.png
# ---
# name: earth-sat-31
# ---
# ```
